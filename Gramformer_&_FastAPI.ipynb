# %% [markdown]
# <a href="https://colab.research.google.com/github/twilight2001/Gramformer/blob/main/Copy_of_OpenSource_Grammarly_API_Alternative_with_Gramformer_%26_FastAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/PrithivirajDamodaran/Gramformer.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/PrithivirajDamodaran/Gramformer.git
#   Cloning https://github.com/PrithivirajDamodaran/Gramformer.git to /tmp/pip-req-build-o_y6olt4
#   Running command git clone --filter=blob:none --quiet https://github.com/PrithivirajDamodaran/Gramformer.git /tmp/pip-req-build-o_y6olt4
#   Resolved https://github.com/PrithivirajDamodaran/Gramformer.git to commit 23425cd2e98a919384cab6156af8adf1c9d0639a
#   Preparing metadata (setup.py) ... done
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 47.2 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.8 MB/s eta 0:00:00
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.20.9-py3-none-any.whl (9.4 kB)
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting tokenizers
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from gramformer==1.0) (2023.1.0)
# Collecting errant
#   Downloading errant-2.3.3-py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.5/499.5 KB 12.4 MB/s eta 0:00:00
# Collecting rapidfuzz>=2.0.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.9 MB/s eta 0:00:00
# Collecting spacy<3,>=2.2.0
#   Downloading spacy-2.3.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 54.6 MB/s eta 0:00:00
# Collecting Levenshtein==0.20.9
#   Downloading Levenshtein-0.20.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.0/174.0 KB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers->gramformer==1.0) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers->gramformer==1.0) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers->gramformer==1.0) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers->gramformer==1.0) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers->gramformer==1.0) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers->gramformer==1.0) (23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers->gramformer==1.0) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers->gramformer==1.0) (4.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (0.10.1)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (0.7.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (3.0.8)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 KB 14.3 MB/s eta 0:00:00
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 40.1 MB/s eta 0:00:00
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers->gramformer==1.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers->gramformer==1.0) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers->gramformer==1.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers->gramformer==1.0) (2022.12.7)
# Building wheels for collected packages: gramformer
#   Building wheel for gramformer (setup.py) ... done
#   Created wheel for gramformer: filename=gramformer-1.0-py3-none-any.whl size=4485 sha256=d2f485f4169ab0e66d0184494df51d2272de564fb2d468dc985478e869c6a6f4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2kaltliu/wheels/fc/6b/60/eaf839540721c457b49785aa12744772957896aed0dba01189
# Successfully built gramformer
# Installing collected packages: tokenizers, sentencepiece, plac, fuzzywuzzy, srsly, rapidfuzz, catalogue, thinc, Levenshtein, huggingface-hub, transformers, spacy, python-Levenshtein, errant, gramformer
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.5
#     Uninstalling srsly-2.4.5:
#       Successfully uninstalled srsly-2.4.5
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.7
#     Uninstalling thinc-8.1.7:
#       Successfully uninstalled thinc-8.1.7
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 2.3.9 which is incompatible.
# confection 0.0.4 requires srsly<3.0.0,>=2.4.0, but you have srsly 1.0.6 which is incompatible.
# Successfully installed Levenshtein-0.20.9 catalogue-1.0.2 errant-2.3.3 fuzzywuzzy-0.18.0 gramformer-1.0 huggingface-hub-0.12.0 plac-1.1.3 python-Levenshtein-0.20.9 rapidfuzz-2.13.7 sentencepiece-0.1.97 spacy-2.3.9 srsly-1.0.6 thinc-7.4.6 tokenizers-0.13.2 transformers-4.26.1

# %%
from gramformer import Gramformer
import torch

def set_seed(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# %%
# !python -m spacy download en_core_web_md
# !python -m spacy link en_core_web_md en
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en_core_web_md==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.3.1/en_core_web_md-2.3.1.tar.gz (50.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 MB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from en_core_web_md==2.3.1) (2.3.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.21.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (4.64.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (57.4.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (0.7.9)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.25.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (0.10.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.2)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (7.4.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.0.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2022.12.7)
# Building wheels for collected packages: en_core_web_md
#   Building wheel for en_core_web_md (setup.py) ... done
#   Created wheel for en_core_web_md: filename=en_core_web_md-2.3.1-py3-none-any.whl size=50916639 sha256=b4cc5165ddc8671a2552debfd8fbef74c2e6cd81b3c44d07cf542a202f4f2a7d
#   Stored in directory: /root/.cache/pip/wheels/b8/ae/ae/c63bae74a3b3e18b2fa35e179387e6cdeb03a1c479ed45c351
# Successfully built en_core_web_md
# Installing collected packages: en_core_web_md
# Successfully installed en_core_web_md-2.3.1
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')
# ✔ Linking successful
# /usr/local/lib/python3.8/dist-packages/en_core_web_md -->
# /usr/local/lib/python3.8/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
gf = Gramformer(models = 1, use_gpu=False) # 0=detector, 1=highlighter, 2=corrector, 3=all
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.89k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Downloading (…)"spiece.model";:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/892M [00:00<?, ?B/s]
# [Gramformer] Grammar error correct/highlight model loaded..

# %%
PATH = "/content/sample_data/gf.pth"

# %%
torch.save(gf, PATH)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1364d301955d> in <module>
# ----> 1 torch.save(gf, PATH)
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     421     if _use_new_zipfile_serialization:
#     422         with _open_zipfile_writer(f) as opened_zipfile:
# --> 423             _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     424             return
#     425     else:
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     633     pickler = pickle_module.Pickler(data_buf, protocol=pickle_protocol)
#     634     pickler.persistent_id = persistent_id
# --> 635     pickler.dump(obj)
#     636     data_value = data_buf.getvalue()
#     637     zip_file.write_record('data.pkl', data_value, len(data_value))
#
# TypeError: cannot pickle 'module' object

# %%
gf_inference = torch.load(PATH)

# %%
influent_sentences = [
    "India is the good country for cricket games",
    "United States has offer help to India"
]

# %%
for influent_sentence in influent_sentences:
    corrected_sentence = gf_inference.correct(influent_sentence)
    print("[Input] ", influent_sentence)
    print("[Correction] ",corrected_sentence[0])
    print("-" *100)
# Out:
# [Input]  India is the good country for cricket games
# [Correction]  India is a good country for cricket.
# ----------------------------------------------------------------------------------------------------
# [Input]  United States has offer help to India
# [Correction]  The United States has offered help to India.
# ----------------------------------------------------------------------------------------------------

# %%
influent_sentences = [
    "When I does something, It're always for your good",
    "This isn't how I like to ate food but that's what life give me "
]   

for influent_sentence in influent_sentences:
    corrected_sentence = gf_inference.correct(influent_sentence)
    print("[Input] ", influent_sentence)
    print("[Correction] ",corrected_sentence[0])
    print("-" *100)
# Out:
# [Input]  When I does something, It're always for your good
# [Correction]  When I do something, it's always for your good.
# ----------------------------------------------------------------------------------------------------
# [Input]  This isn't how I like to ate food but that's what life give me
# [Correction]  This isn't how I like to eat food but that's what life gives me
# ----------------------------------------------------------------------------------------------------

# %%
# !pip install colabcode -q 
# !pip install fastapi -q
# Out:
#      |████████████████████████████████| 51kB 2.8MB/s
#      |████████████████████████████████| 747kB 7.8MB/s
#      |████████████████████████████████| 8.3MB 10.7MB/s
#      |████████████████████████████████| 61kB 6.9MB/s
#      |████████████████████████████████| 389kB 40.5MB/s
#      |████████████████████████████████| 61kB 6.6MB/s
#      |████████████████████████████████| 430kB 39.2MB/s
#      |████████████████████████████████| 122kB 44.3MB/s
#      |████████████████████████████████| 71kB 7.4MB/s
#      |████████████████████████████████| 81kB 7.1MB/s
#      |████████████████████████████████| 61kB 6.2MB/s
#   Building wheel for pyngrok (setup.py) ... done
# ERROR: google-colab 1.0.0 has requirement tornado~=5.1.0; python_version >= "3.0", but you'll have tornado 6.1 which is incompatible.
#      |████████████████████████████████| 51kB 3.1MB/s
#      |████████████████████████████████| 10.1MB 7.7MB/s
#      |████████████████████████████████| 61kB 6.0MB/s

# %%
from colabcode import ColabCode
from fastapi import FastAPI

# %%
cc = ColabCode(port=12000, code=False)

# %%
app = FastAPI(title="OpenSource Grammarly API Alternative", description="with Gramformer & FastAPI", version="1.0")

# # Initialize logging
# my_logger = logging.getLogger()
# my_logger.setLevel(logging.DEBUG)
# logging.basicConfig(level=logging.DEBUG, filename='logs.log')

gf_inference = None

@app.on_event("startup")
def load_model():
    global gf_inference
    gf_inference = torch.load(PATH)

@app.post("/api/{sentence}")
async def get_predictions(sentence: str):
    try:
       # sentence = "This isn't how I like to ate food but that's what life give me"
        output_sentence = gf_inference.correct(sentence)
        return {"prediction": output_sentence[0]}
    except:
        my_logger.error("Something went wrong!")
        return {"prediction": "error"}

# %%
cc.run_app(app=app)
# Out:
# Public URL: NgrokTunnel: "http://ad43e45519f2.ngrok.io" -> "http://localhost:12000"
# INFO:     Started server process [58]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:12000 (Press CTRL+C to quit)
# INFO:     49.207.209.194:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     49.207.209.194:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     49.207.209.194:0 - "GET /api/he%20like%20me%20so%20much HTTP/1.1" 405 Method Not Allowed
# INFO:     49.207.209.194:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     49.207.209.194:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     49.207.209.194:0 - "POST /api/He%20like%20me%20so%20much%20 HTTP/1.1" 200 OK
# INFO:     49.207.209.194:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     49.207.209.194:0 - "POST /api/I%20love%20write%20because%20it%20give%20me%20pleasure HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [58]
